# %% [markdown]
# # Exploratory Data Analysis
# Run the EDA stage from the training pipeline.

# %%
from src.preprocessing import load_and_validate
from train_pipeline import make_eda
df, _ = load_and_validate()
make_eda(df)
