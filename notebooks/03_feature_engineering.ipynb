# %% [markdown]
# # Feature Engineering
# Create grouped lag and shifted rolling features without target leakage.

# %%
from src.preprocessing import load_and_validate
from src.feature_engineering import add_features
df, _ = load_and_validate()
features = add_features(df)
features.head()
