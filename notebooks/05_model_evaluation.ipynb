# %% [markdown]
# # Model Evaluation
# Review actual metrics generated by the chronological holdout.

# %%
import pandas as pd
metrics = pd.read_csv('../results/metrics/model_comparison.csv')
metrics
